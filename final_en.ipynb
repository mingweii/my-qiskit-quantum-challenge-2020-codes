# %%
from IPython.display import Image, display
Image("ryoko.png", width="70")

# %% [markdown]
# # The Final Stage

# %% [markdown]
# *Dr. Ryoko is stuck in the quantum multiverse due to noise clusters interfering with her device. <br/>
# Please DM Dr. Ryoko and ask her about the **noise clusters** and you will find out more. <br/>
# Dr. Ryoko is trying to clear noise clusters with her laser beams, but has only 3 shots left.<br/>
# To make matters worse, there seems to be one area (board) that cannot be cleared within 3 shots. <br/>
# Help Dr. Ryoko identify that one area (board) with noise clusters that **cannot be cleared within 3 shots**. Good luck!<br/>*
#
# [<< Click here to communicate with Dr. Ryoko through the web cam >>](https://youtu.be/Bkk5-j6rpoM)
#
# *You can do this by learning how to solve a famous classic puzzle called “Asteroids puzzle”.*

# %% [markdown]
# # Week3: False Asteroids
# Asteroids is a famous puzzle with the following setup and rules:
# - The asteroids are placed on a grid.
# - The objective is to destroy all the asteroids by shooting laser beams: either vertically or horizontally.
# - Determine how to destroy all the asteroids by shooting no more than the specified number of beams.
#
# The following image is an example of an Asteroids puzzle. In this example, the board size is 4 × 4 and we have six asteroids.

# %%
Image('asteroids_example.png')

# %% [markdown]
# As shown below, we can destroy all the asteroids by shooting 3 lasers vertically. Each thick blue line represents a laser beam.

# %%
Image('asteroids_beam_example.png')

# %% [markdown]
# There are also false Asteroid problems. An Asteroid problem is false if the asteroids cannot be cleared within the specified number of beams. The following example is a false Asteroid problem with 3 laser beams.

# %%
Image('false_asteroids_example.png')

# %% [markdown]
# ----------
# # Final Exercise
# There are 16 areas (boards) that Dr. Ryoko needs to clear, each of which has 6 noise clusters that correspond to an asteroid in "Asteroids puzzle". However, there happens to be one area that cannot be cleared within three laser shots! Use Grover's algorithm you learned in Weeks 1 & 2 to find that one area (board)!

# %% [markdown]
# A board with asteroids is represented with a list of tuples. Each tuple represents the coordinate of an asteroid in the format `[row index, column index]`. Therefore, a board according to the following image can be represented as:
#
# ```
# [['0', '0'], ['1', '1'], ['2', '2'], ['3', '0'], ['3', '1'], ['3', '2']]
# ```

# %%
Image('asteroids_example.png')

# %% [markdown]
# There are 16 areas (boards) with the following configurations.
# Find the area that cannot be cleared with 3 laser shots by using Grover's algorithm to help Dr. Ryoko!

# %%
problem_set = \
    [[['0', '2'], ['1', '0'], ['1', '2'], ['1', '3'], ['2', '0'], ['3', '3']],
    [['0', '0'], ['0', '1'], ['1', '2'], ['2', '2'], ['3', '0'], ['3', '3']],
    [['0', '0'], ['1', '1'], ['1', '3'], ['2', '0'], ['3', '2'], ['3', '3']],
    [['0', '0'], ['0', '1'], ['1', '1'], ['1', '3'], ['3', '2'], ['3', '3']],
    [['0', '2'], ['1', '0'], ['1', '3'], ['2', '0'], ['3', '2'], ['3', '3']],
    [['1', '1'], ['1', '2'], ['2', '0'], ['2', '1'], ['3', '1'], ['3', '3']],
    [['0', '2'], ['0', '3'], ['1', '2'], ['2', '0'], ['2', '1'], ['3', '3']],
    [['0', '0'], ['0', '3'], ['1', '2'], ['2', '2'], ['2', '3'], ['3', '0']],
    [['0', '3'], ['1', '1'], ['1', '2'], ['2', '0'], ['2', '1'], ['3', '3']],
    [['0', '0'], ['0', '1'], ['1', '3'], ['2', '1'], ['2', '3'], ['3', '0']],
    [['0', '1'], ['0', '3'], ['1', '2'], ['1', '3'], ['2', '0'], ['3', '2']],
    [['0', '0'], ['1', '3'], ['2', '0'], ['2', '1'], ['2', '3'], ['3', '1']],
    [['0', '1'], ['0', '2'], ['1', '0'], ['1', '2'], ['2', '2'], ['2', '3']],
    [['0', '3'], ['1', '0'], ['1', '3'], ['2', '1'], ['2', '2'], ['3', '0']],
    [['0', '2'], ['0', '3'], ['1', '2'], ['2', '3'], ['3', '0'], ['3', '1']],
    [['0', '1'], ['1', '0'], ['1', '2'], ['2', '2'], ['3', '0'], ['3', '1']]]

# %% [markdown]
# Answer by creating a quantum circuit to solve the puzzle shown with the problem set above. In the quantum circuit to be submitted, measure **only the `solution` (4bit)** that solves the puzzle. <br/>
# To submit your solution, create a function that takes `problem_set` as an input and then returns a  `QuantumCircuit`.  You can name the function as you like. Make sure it works even with another dataset of "problem_set". We will validate your circuit with different inputs.<br/>
# Make a circuit that gets the correct answer at a low cost. The lower the cost, the better.
#
# ## <span style="color: red; ">IMPORTANT: Final exercise submission rules</span>
#
# **For solving this problem:**<br/>
# - **Please implement the quantum circuit within <span style="color: red; ">28 qubits.</span>**<br/>
# - Use **Grover's algorithm** you learned in Week1 & 2 with **<span style="color: red; ">iteration ＝ 1.</span>**
# - The initial state for Grover's algorithm must be equal probability distributions. For example, if you want use only 3 computational bases for 2 qubits instead of 4 as the initial state. Then, the state will be $\sqrt\frac{1}{3} (|00\rangle + |01\rangle + |11\rangle)$
#
# - Please note that you can get the answer with the same endian as the one used in Week2 explanation. You should map the index of the problem into four classical registers *`c[0:4]`* in binary. `c[0]` is the highest bit and `c[3]` is the lowest bit. For example, when mapping 12, the furthest left bit of the `1100` will be mapped to `c[0]`.
# - Make sure you **create an oracle** that **doesn't require any knowledge of what the answers are**. (For example, you are not allowed to create an oracle by using a classical optimization solver to get your answers for it.)
# - With the exception of the Unroller, which is required for decomposing your circuit to calculate quantum costs, you are not allowed to use any existing transpiler passes nor original transpilers for making simplifications in this competition.
# - Please **do not run jobs in succession** even if you are concerned that your job is not running properly. This can create a long queue and clog the backend. You can check whether your job is running properly at:<br/>
# https://quantum-computing.ibm.com/results
# - Your score for this exercise will be same as the cost of your QuantumCircuit. The lower the cost, the better.
# - Judges will check top 10 solutions manually to see if their solutions adhere to the rules. **Please note that your ranking is subject to change after the challenge period as a result of the judging process.**
# - Top 10 participants will be recognized and asked to submit a write up on how they solved the exercise.

# %%
from qiskit import *
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit import IBMQ, Aer, execute
provider = IBMQ.load_account()
# Out:
# /opt/conda/lib/python3.7/site-packages/qiskit/providers/ibmq/ibmqfactory.py:192: UserWarning: Timestamps in IBMQ backend properties, jobs, and job results are all now in local time instead of UTC.
#   warnings.warn('Timestamps in IBMQ backend properties, jobs, and job results '

# %%
def week3_ans_func(problem_set):
    ##### build your quantum circuit here
    ##### In addition, please make it a function that can solve the problem even with different inputs (problem_set). We do validation with different inputs. 
    
    
    address = QuantumRegister(4,'address') # 0000 to 1111, representing the number of solvable boards.
    board=QuantumRegister(16,'board')

    auxiliary= QuantumRegister(2,'ancilla')
    aux_qram=QuantumRegister(2,'aux_qram')
    oracle=QuantumRegister(1,'oracle')
    c = ClassicalRegister(4)
    qc = QuantumCircuit(address, board, auxiliary,aux_qram,oracle,c)
    #Qubit initialize
    qc.h([address[0],address[1],address[2],address[3]])
    qc.x(oracle)
    qc.h(oracle)
    def qram():
        # address 0 -> board0
        qc.x([address[0],address[1],address[2],address[3]])
        for i in range(len(problem_set[0])):
            qc.mct(address[0:4],board[int(problem_set[0][i][0])*4+int(problem_set[0][i][1])],aux_qram[:],mode='basic')
        qc.x([address[0]])#,address[1],address[2],address[3]]) # reduce cost
        qc.barrier()  
        # address 1 -> board1
        #qc.x([address[1],address[2],address[3]])# reduce cost
        for i in range(len(problem_set[1])):
            qc.mct(address[0:4],board[int(problem_set[1][i][0])*4+int(problem_set[1][i][1])],aux_qram[:],mode='basic')
        qc.x([address[1]])#,address[2],address[3]])# reduce cost
        qc.barrier()
        # address 2 -> board2
        qc.x([address[0]])#,address[2],address[3]])# reduce cost
        for i in range(len(problem_set[2])):
            qc.mct(address[0:4],board[int(problem_set[2][i][0])*4+int(problem_set[2][i][1])],aux_qram[:],mode='basic')
        qc.x([address[0]])#,address[2],address[3]]) # reduce cost
        qc.barrier()
        # address 3 -> board3
        #qc.x([address[2],address[3]]) # reduce cost
        for i in range(len(problem_set[3])):
            qc.mct(address[0:4],board[int(problem_set[3][i][0])*4+int(problem_set[3][i][1])],aux_qram[:],mode='basic')
        qc.x([address[2]])#,address[3]]) # reduce cost
        qc.barrier()
        # address 4 -> board4
        qc.x([address[0],address[1]])#,address[3]]) # reduce cost
        for i in range(len(problem_set[4])):
            qc.mct(address[0:4],board[int(problem_set[4][i][0])*4+int(problem_set[4][i][1])],aux_qram[:],mode='basic')
        qc.x([address[0]])#,address[1],address[3]]) # reduce cost
        qc.barrier()  
        # address 5 -> board5
        #qc.x([address[1],address[3]])
        for i in range(len(problem_set[5])):
            qc.mct(address[0:4],board[int(problem_set[5][i][0])*4+int(problem_set[5][i][1])],aux_qram[:],mode='basic')
        qc.x([address[1]])#,address[3]]) # reduce cost
        qc.barrier()
        # address 6 -> board6
        qc.x([address[0]])#,address[3]]) # reduce cost
        for i in range(len(problem_set[6])):
            qc.mct(address[0:4],board[int(problem_set[6][i][0])*4+int(problem_set[6][i][1])],aux_qram[:],mode='basic')
        qc.x([address[0]])#,address[3]]) # reduce cost
        qc.barrier()
        # address 7 -> board7
        #qc.x(address[3])# reduce cost
        for i in range(len(problem_set[7])):
            qc.mct(address[0:4],board[int(problem_set[7][i][0])*4+int(problem_set[7][i][1])],aux_qram[:],mode='basic')
        qc.x(address[3])
        qc.barrier()
        # address 8 -> board8
        qc.x([address[0],address[1],address[2]])
        for i in range(len(problem_set[8])):
            qc.mct(address[0:4],board[int(problem_set[8][i][0])*4+int(problem_set[8][i][1])],aux_qram[:],mode='basic')
        qc.x([address[0]])#,address[1],address[2]]) # reduce cost
        qc.barrier()  
        # address 9 -> board9
        #qc.x([address[1],address[2]]) # reduce cost
        for i in range(len(problem_set[9])):
            qc.mct(address[0:4],board[int(problem_set[9][i][0])*4+int(problem_set[9][i][1])],aux_qram[:],mode='basic')
        qc.x([address[1]])#,address[2]]) # reduce cost
        qc.barrier()
        # address 10 -> board10
        qc.x([address[0]])#,address[2]]) # reduce cost
        for i in range(len(problem_set[10])):
            qc.mct(address[0:4],board[int(problem_set[10][i][0])*4+int(problem_set[10][i][1])],aux_qram[:],mode='basic')
        qc.x([address[0]])#,address[2]]) # reduce cost
        qc.barrier()
        # address 11 -> board11
        #qc.x(address[2]) # reduce cost
        for i in range(len(problem_set[11])):
            qc.mct(address[0:4],board[int(problem_set[11][i][0])*4+int(problem_set[11][i][1])],aux_qram[:],mode='basic')
        qc.x(address[2])
        qc.barrier()
        # address 12 -> board12
        qc.x([address[0],address[1]])
        for i in range(len(problem_set[12])):
            qc.mct(address[0:4],board[int(problem_set[12][i][0])*4+int(problem_set[12][i][1])],aux_qram[:],mode='basic')
        qc.x([address[0]])#,address[1]]) # reduce cost
        qc.barrier()  
        # address 13 -> board13
        #qc.x(address[1])
        for i in range(len(problem_set[13])):
            qc.mct(address[0:4],board[int(problem_set[13][i][0])*4+int(problem_set[13][i][1])],aux_qram[:],mode='basic')
        qc.x(address[1])
        qc.barrier()
        # address 14 -> board14
        qc.x(address[0])
        for i in range(len(problem_set[14])):
            qc.mct(address[0:4],board[int(problem_set[14][i][0])*4+int(problem_set[14][i][1])],aux_qram[:],mode='basic')
        qc.x(address[0])
        qc.barrier()
        # address 15 -> board15
        for i in range(len(problem_set[15])):
            #qc.mct([address[0:4],h[int(problem_set[15][i][0])],v[int(problem_set[15][i][1])]],asteroid[i])
            qc.mct(address[0:4],board[int(problem_set[15][i][0])*4+int(problem_set[15][i][1])],aux_qram[:],mode='basic')
        qc.barrier()
    def qram_inv():
        # address 15 -> board15
        for i in range(len(problem_set[15])):
            #qc.mct([address[0:4],h[int(problem_set[15][i][0])],v[int(problem_set[15][i][1])]],asteroid[i])
            qc.mct(address[0:4],board[int(problem_set[15][i][0])*4+int(problem_set[15][i][1])],aux_qram[:],mode='basic')
        qc.barrier()
        # address 14 -> board14
        qc.x(address[0])
        for i in range(len(problem_set[14])):
            qc.mct(address[0:4],board[int(problem_set[14][i][0])*4+int(problem_set[14][i][1])],aux_qram[:],mode='basic')
        qc.x(address[0])
        qc.barrier()
        # address 13 -> board13
        qc.x(address[1])
        for i in range(len(problem_set[13])):
            qc.mct(address[0:4],board[int(problem_set[13][i][0])*4+int(problem_set[13][i][1])],aux_qram[:],mode='basic')
        #qc.x(address[1])
        qc.barrier()
        # address 12 -> board12
        qc.x([address[0]])#,address[1]]) # reduce cost
        for i in range(len(problem_set[12])):
            qc.mct(address[0:4],board[int(problem_set[12][i][0])*4+int(problem_set[12][i][1])],aux_qram[:],mode='basic')
        qc.x([address[0],address[1]])
        qc.barrier() 
         # address 11 -> board11
        qc.x(address[2]) 
        for i in range(len(problem_set[11])):
            qc.mct(address[0:4],board[int(problem_set[11][i][0])*4+int(problem_set[11][i][1])],aux_qram[:],mode='basic')
        #qc.x(address[2])# reduce cost
        qc.barrier()
        # address 10 -> board10
        qc.x([address[0]])#,address[2]]) # reduce cost
        for i in range(len(problem_set[10])):
            qc.mct(address[0:4],board[int(problem_set[10][i][0])*4+int(problem_set[10][i][1])],aux_qram[:],mode='basic')
        qc.x([address[0]])#,address[2]]) # reduce cost
        qc.barrier()
        # address 9 -> board9
        qc.x([address[1]])#,address[2]]) # reduce cost
        for i in range(len(problem_set[9])):
            qc.mct(address[0:4],board[int(problem_set[9][i][0])*4+int(problem_set[9][i][1])],aux_qram[:],mode='basic')
        #qc.x([address[1],address[2]]) # reduce cost
        qc.barrier()
        # address 8 -> board8
        qc.x([address[0]])#,address[1],address[2]]) # reduce cost
        for i in range(len(problem_set[8])):
            qc.mct(address[0:4],board[int(problem_set[8][i][0])*4+int(problem_set[8][i][1])],aux_qram[:],mode='basic')
        qc.x([address[0],address[1],address[2]])
        qc.barrier() 
        # address 7 -> board7
        qc.x(address[3])
        for i in range(len(problem_set[7])):
            qc.mct(address[0:4],board[int(problem_set[7][i][0])*4+int(problem_set[7][i][1])],aux_qram[:],mode='basic')
        #qc.x(address[3])# reduce cost
        qc.barrier()
        # address 6 -> board6
        qc.x([address[0]])#,address[3]]) # reduce cost
        for i in range(len(problem_set[6])):
            qc.mct(address[0:4],board[int(problem_set[6][i][0])*4+int(problem_set[6][i][1])],aux_qram[:],mode='basic')
        qc.x([address[0]])#,address[3]]) # reduce cost
        qc.barrier()
        # address 5 -> board5
        qc.x([address[1]])#,address[3]]) # reduce cost
        for i in range(len(problem_set[5])):
            qc.mct(address[0:4],board[int(problem_set[5][i][0])*4+int(problem_set[5][i][1])],aux_qram[:],mode='basic')
        #qc.x([address[1],address[3]])
        qc.barrier()
        # address 4 -> board4
        qc.x([address[0]])#,address[1],address[3]]) # reduce cost
        for i in range(len(problem_set[4])):
            qc.mct(address[0:4],board[int(problem_set[4][i][0])*4+int(problem_set[4][i][1])],aux_qram[:],mode='basic')
        qc.x([address[0],address[1]])#,address[3]]) # reduce cost
        qc.barrier() 
        # address 3 -> board3
        qc.x([address[2]])#,address[3]]) # reduce cost
        for i in range(len(problem_set[3])):
            qc.mct(address[0:4],board[int(problem_set[3][i][0])*4+int(problem_set[3][i][1])],aux_qram[:],mode='basic')
        #qc.x([address[2],address[3]]) # reduce cost
        qc.barrier()
        # address 2 -> board2
        qc.x([address[0]])#,address[2],address[3]])# reduce cost
        for i in range(len(problem_set[2])):
            qc.mct(address[0:4],board[int(problem_set[2][i][0])*4+int(problem_set[2][i][1])],aux_qram[:],mode='basic')
        qc.x([address[0]])#,address[2],address[3]]) # reduce cost
        qc.barrier()
        # address 1 -> board1
        qc.x([address[1]])#,address[2],address[3]])# reduce cost
        for i in range(len(problem_set[1])):
            qc.mct(address[0:4],board[int(problem_set[1][i][0])*4+int(problem_set[1][i][1])],aux_qram[:],mode='basic')
        #qc.x([address[1],address[2],address[3]])# reduce cost
        qc.barrier()
        # address 0 -> board0
        qc.x([address[0]])#,address[1],address[2],address[3]]) # reduce cost
        for i in range(len(problem_set[0])):
            qc.mct(address[0:4],board[int(problem_set[0][i][0])*4+int(problem_set[0][i][1])],aux_qram[:],mode='basic')
        qc.x([address[0],address[1],address[2],address[3]])
        qc.barrier()  

    #### Code for Grover's algorithm with iterations = 1 will be as follows. 
    def oracle_ex3():
        qc.mct([board[0],board[5],board[10],board[15]],oracle,auxiliary[:],mode='basic')
        qc.mct([board[0],board[5],board[11],board[14]],oracle,auxiliary[:],mode='basic')
        qc.mct([board[0],board[6],board[11],board[13]],oracle,auxiliary[:],mode='basic')
        qc.mct([board[0],board[6],board[9],board[15]],oracle,auxiliary[:],mode='basic')
        qc.mct([board[0],board[7],board[9],board[14]],oracle,auxiliary[:],mode='basic')
        qc.mct([board[0],board[7],board[10],board[13]],oracle,auxiliary[:],mode='basic')
        qc.mct([board[1],board[6],board[11],board[12]],oracle,auxiliary[:],mode='basic')
        qc.mct([board[1],board[6],board[8],board[15]],oracle,auxiliary[:],mode='basic')
        qc.mct([board[1],board[7],board[10],board[12]],oracle,auxiliary[:],mode='basic')
        qc.mct([board[1],board[7],board[8],board[14]],oracle,auxiliary[:],mode='basic')
        qc.mct([board[1],board[4],board[10],board[15]],oracle,auxiliary[:],mode='basic')
        qc.mct([board[1],board[4],board[11],board[14]],oracle,auxiliary[:],mode='basic')
        qc.mct([board[2],board[7],board[8],board[13]],oracle,auxiliary[:],mode='basic')
        qc.mct([board[2],board[7],board[9],board[12]],oracle,auxiliary[:],mode='basic')
        qc.mct([board[2],board[4],board[9],board[15]],oracle,auxiliary[:],mode='basic')
        qc.mct([board[2],board[4],board[11],board[13]],oracle,auxiliary[:],mode='basic')
        qc.mct([board[2],board[5],board[8],board[15]],oracle,auxiliary[:],mode='basic')
        qc.mct([board[2],board[5],board[11],board[12]],oracle,auxiliary[:],mode='basic')
        qc.mct([board[3],board[4],board[9],board[14]],oracle,auxiliary[:],mode='basic')
        qc.mct([board[3],board[4],board[10],board[13]],oracle,auxiliary[:],mode='basic')
        qc.mct([board[3],board[5],board[8],board[14]],oracle,auxiliary[:],mode='basic')
        qc.mct([board[3],board[5],board[10],board[12]],oracle,auxiliary[:],mode='basic')
        qc.mct([board[3],board[6],board[8],board[13]],oracle,auxiliary[:],mode='basic')
        qc.mct([board[3],board[6],board[9],board[12]],oracle,auxiliary[:],mode='basic')
        qc.barrier()
    qram()
    for i in range(1):
        oracle_ex3()
    qram_inv()
    
    qc.h(address[:4])
    qc.x(address[:4])
    qc.h(address[3])
    qc.mct(address[0:3], address[3],aux_qram[:],mode='basic')
    qc.h(address[3])
    qc.x(address[:4])
    qc.h(address[:4])
    #qc.h(oracle)
    #qc.x(oracle)
    qc.measure(address[0], c[3])
    qc.measure(address[1], c[2])
    qc.measure(address[2], c[1]) 
    qc.measure(address[3], c[0])
    return qc

# %%
qc=week3_ans_func(problem_set)
qc.draw(output="mpl")

# %%
help(qc.mct)
# Out:
# Help on method mct in module qiskit.circuit.quantumcircuit:
#
# mct(control_qubits, target_qubit, ancilla_qubits=None, mode='noancilla') method of qiskit.circuit.quantumcircuit.QuantumCircuit instance
#     Apply :class:`~qiskit.circuit.library.MCXGate`.

# %%
q1 = [[[['0', '1'], ['0', '2'], ['1', '0'], ['2', '0'], ['3', '1'], ['3', '3']],
 [['0', '2'], ['0', '3'], ['1', '1'], ['1', '3'], ['2', '0'], ['2', '1']],
 [['0', '0'], ['0', '3'], ['2', '1'], ['2', '2'], ['3', '0'], ['3', '1']],
 [['0', '0'], ['0', '1'], ['0', '2'], ['1', '1'], ['2', '0'], ['3', '2']],
 [['0', '1'], ['1', '2'], ['1', '3'], ['2', '0'], ['3', '0'], ['3', '1']],
 [['0', '2'], ['0', '3'], ['1', '1'], ['2', '0'], ['2', '1'], ['3', '0']],
 [['0', '0'], ['0', '3'], ['1', '2'], ['2', '0'], ['2', '1'], ['3', '3']],
 [['0', '2'], ['1', '1'], ['1', '3'], ['2', '0'], ['2', '3'], ['3', '2']],
 [['0', '1'], ['0', '3'], ['2', '0'], ['2', '2'], ['3', '0'], ['3', '3']],
 [['0', '0'], ['0', '2'], ['1', '0'], ['2', '2'], ['2', '3'], ['3', '3']],
 [['1', '0'], ['1', '3'], ['2', '1'], ['2', '2'], ['3', '2'], ['3', '3']],
 [['0', '0'], ['1', '0'], ['2', '1'], ['2', '2'], ['3', '2'], ['3', '3']],
 [['0', '0'], ['1', '1'], ['1', '2'], ['2', '1'], ['2', '3'], ['3', '0']],
 [['0', '1'], ['0', '3'], ['2', '1'], ['2', '2'], ['3', '0'], ['3', '1']],
 [['0', '0'], ['0', '1'], ['1', '1'], ['1', '3'], ['3', '2'], ['3', '3']],
 [['0', '0'], ['0', '3'], ['1', '2'], ['1', '3'], ['3', '0'], ['3', '1']]], '6']

q2 = [[[['0', '0'], ['0', '2'], ['1', '0'], ['1', '1'], ['3', '1'], ['3', '3']],
 [['0', '2'], ['0', '3'], ['1', '1'], ['1', '3'], ['2', '0'], ['2', '1']],
 [['0', '0'], ['1', '0'], ['2', '1'], ['2', '3'], ['3', '2'], ['3', '3']],
 [['0', '2'], ['0', '3'], ['1', '1'], ['1', '2'], ['3', '0'], ['3', '2']],
 [['0', '2'], ['0', '3'], ['2', '0'], ['2', '1'], ['3', '1'], ['3', '3']],
 [['0', '1'], ['0', '3'], ['1', '2'], ['1', '3'], ['2', '2'], ['3', '1']],
 [['0', '0'], ['1', '0'], ['2', '2'], ['2', '3'], ['3', '1'], ['3', '3']],
 [['0', '0'], ['0', '1'], ['1', '2'], ['2', '0'], ['3', '1'], ['3', '2']],
 [['0', '1'], ['0', '2'], ['1', '0'], ['1', '3'], ['3', '0'], ['3', '1']],
 [['0', '0'], ['0', '2'], ['1', '0'], ['1', '3'], ['2', '1'], ['2', '2']],
 [['0', '0'], ['0', '1'], ['0', '3'], ['1', '0'], ['2', '1'], ['3', '3']],
 [['0', '0'], ['0', '3'], ['1', '1'], ['1', '3'], ['2', '0'], ['2', '2']],
 [['0', '1'], ['1', '3'], ['2', '0'], ['2', '1'], ['2', '3'], ['3', '0']],
 [['0', '0'], ['1', '1'], ['2', '0'], ['2', '3'], ['3', '1'], ['3', '2']],
 [['0', '0'], ['0', '3'], ['1', '2'], ['2', '2'], ['3', '1'], ['3', '3']],
 [['0', '2'], ['0', '3'], ['1', '0'], ['1', '2'], ['2', '1'], ['2', '2']]], '13']

q3 = [[[['0', '2'], ['0', '3'], ['1', '1'], ['2', '0'], ['3', '0'], ['3', '1']],
 [['0', '1'], ['0', '3'], ['2', '0'], ['2', '2'], ['3', '0'], ['3', '1']],
 [['0', '0'], ['0', '3'], ['1', '1'], ['1', '3'], ['2', '2'], ['2', '3']],
 [['0', '2'], ['0', '3'], ['1', '0'], ['1', '1'], ['2', '3'], ['3', '1']],
 [['0', '1'], ['0', '2'], ['1', '0'], ['2', '0'], ['2', '3'], ['3', '3']],
 [['0', '3'], ['1', '0'], ['1', '2'], ['2', '1'], ['2', '2'], ['3', '3']],
 [['0', '1'], ['0', '3'], ['2', '0'], ['2', '3'], ['3', '2'], ['3', '3']],
 [['1', '0'], ['1', '1'], ['2', '1'], ['2', '3'], ['3', '2'], ['3', '3']],
 [['0', '1'], ['0', '2'], ['1', '0'], ['1', '3'], ['2', '3'], ['3', '0']],
 [['0', '0'], ['1', '1'], ['1', '3'], ['2', '0'], ['3', '2'], ['3', '3']],
 [['0', '1'], ['0', '2'], ['1', '3'], ['2', '0'], ['3', '0'], ['3', '3']],
 [['0', '0'], ['0', '1'], ['2', '0'], ['2', '3'], ['3', '2'], ['3', '3']],
 [['0', '3'], ['1', '0'], ['1', '2'], ['2', '2'], ['3', '0'], ['3', '3']],
 [['0', '0'], ['0', '3'], ['1', '0'], ['1', '1'], ['2', '0'], ['2', '2']],
 [['0', '1'], ['0', '3'], ['1', '2'], ['2', '0'], ['2', '1'], ['3', '2']],
 [['0', '2'], ['0', '3'], ['1', '3'], ['2', '0'], ['2', '2'], ['3', '0']]], '3']

# %%
qc1=week3_ans_func(q1[0])
qc2=week3_ans_func(q2[0])
qc3=week3_ans_func(q3[0])

# %%
# %%time
from qiskit import IBMQ, execute
provider = IBMQ.load_account()
backend = provider.get_backend('ibmq_qasm_simulator')
job = execute(qc1, backend=backend, shots=8000, seed_simulator=12345, backend_options={"fusion_enable":True})
result = job.result()
count = result.get_counts()
score_sorted = sorted(count.items(), key=lambda x:x[1], reverse=True)
final_score = score_sorted[0:20]
final_score
# Out:
# /opt/conda/lib/python3.7/site-packages/qiskit/providers/ibmq/ibmqfactory.py:192: UserWarning: Timestamps in IBMQ backend properties, jobs, and job results are all now in local time instead of UTC.
#   warnings.warn('Timestamps in IBMQ backend properties, jobs, and job results '
# ibmqfactory.load_account:WARNING:2020-11-30 00:05:54,508: Credentials are already in use. The existing account in the session will be replaced.
# CPU times: user 850 ms, sys: 35.3 ms, total: 885 ms
# Wall time: 1min 15s
# [('0110', 3768),
#  ('1110', 315),
#  ('1010', 298),
#  ('1100', 294),
#  ('1000', 292),
#  ('1001', 290),
#  ('0011', 289),
#  ('0100', 288),
#  ('0111', 279),
#  ('1011', 276),
#  ('0001', 275),
#  ('0101', 274),
#  ('1101', 268),
#  ('0000', 266),
#  ('1111', 266),
#  ('0010', 262)]

# %%
# %%time
from qiskit import IBMQ, execute
provider = IBMQ.load_account()
backend = provider.get_backend('ibmq_qasm_simulator')
job = execute(qc2, backend=backend, shots=8000, seed_simulator=12345, backend_options={"fusion_enable":True})
result = job.result()
count = result.get_counts()
score_sorted = sorted(count.items(), key=lambda x:x[1], reverse=True)
final_score = score_sorted[0:20]
final_score
# Out:
# ibmqfactory.load_account:WARNING:2020-11-30 00:07:09,873: Credentials are already in use. The existing account in the session will be replaced.
# CPU times: user 864 ms, sys: 19 ms, total: 883 ms
# Wall time: 41.5 s
# [('1011', 3818),
#  ('0011', 301),
#  ('1010', 298),
#  ('1100', 294),
#  ('1000', 292),
#  ('0100', 288),
#  ('1110', 285),
#  ('0110', 279),
#  ('0111', 279),
#  ('1101', 279),
#  ('1001', 277),
#  ('0000', 266),
#  ('1111', 266),
#  ('0010', 262),
#  ('0001', 261),
#  ('0101', 255)]

# %%
# %%time
from qiskit import IBMQ, execute
provider = IBMQ.load_account()
backend = provider.get_backend('ibmq_qasm_simulator')
job = execute(qc3, backend=backend, shots=8000, seed_simulator=12345, backend_options={"fusion_enable":True})
result = job.result()
count = result.get_counts()
score_sorted = sorted(count.items(), key=lambda x:x[1], reverse=True)
final_score = score_sorted[0:20]
final_score
# Out:
# ibmqfactory.load_account:WARNING:2020-11-30 00:07:51,109: Credentials are already in use. The existing account in the session will be replaced.
# CPU times: user 2.29 s, sys: 60.7 ms, total: 2.35 s
# Wall time: 2min 54s
# [('1100', 3789),
#  ('1110', 315),
#  ('1000', 292),
#  ('1001', 290),
#  ('0011', 289),
#  ('0100', 288),
#  ('0110', 286),
#  ('0111', 279),
#  ('1011', 276),
#  ('0001', 275),
#  ('0010', 275),
#  ('0101', 274),
#  ('1010', 272),
#  ('1101', 268),
#  ('0000', 266),
#  ('1111', 266)]

# %%
# Submission code
from qc_grader import grade_ex3, prepare_ex3, submit_ex3

# Execute your circuit with following prepare_ex3() function.
# The prepare_ex3() function works like the execute() function with only QuantumCircuit as an argument.
job = prepare_ex3(week3_ans_func)

result = job.result()
counts = result.get_counts()
original_problem_set_counts = counts[0]

original_problem_set_counts
# The bit string with the highest number of observations is treated as the solution.
# Out:
# Running week3_ans_func...
# Computing cost...
# Starting experiments. Please wait...
# You may monitor the job (id: 5fc4514e1dde84001b4c97c7) status and proceed to grading when it successfully completes.
# {'0000': 31,
#  '0001': 42,
#  '0010': 39,
#  '0011': 42,
#  '0100': 31,
#  '0101': 478,
#  '0110': 29,
#  '0111': 32,
#  '1000': 36,
#  '1001': 33,
#  '1010': 40,
#  '1011': 25,
#  '1100': 34,
#  '1101': 40,
#  '1110': 28,
#  '1111': 40}

# %%
# Check your answer by executing following code.
# The quantum cost of the QuantumCircuit is obtained as the score. The lower the cost, the better.
grade_ex3(job)
# Out:
# Grading your answer. Please wait...
#
# Congratulations 🎉! Your answer is correct.
# Your score is 46233.
# The lower your score the better!
# Feel free to submit your answer.

# %%
# Submit your results by executing following code. You can submit as many times as you like during the period. 
submit_ex3(job)
# Out:
# Submitting your answer. Please wait...
#
# Success 🎉! Your answer has been submitted.
# Congratulations! You have rescued Dr. Ryoko from the quantum realm. The bright "quantum future" is ahead.
